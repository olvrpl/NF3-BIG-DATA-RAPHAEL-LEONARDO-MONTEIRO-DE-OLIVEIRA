# %% [markdown]
# <a href="https://colab.research.google.com/github/olvrpl/NF3-BIG-DATA-RAPHAEL-LEONARDO-MONTEIRO-DE-OLIVEIRA/blob/main/C%C3%B3pia_de_Big_Data_Trabalho_Final_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.a) Agrupe os dados por tipo de bebidas;

import pandas as pd
dados = pd.read_csv('https://raw.githubusercontent.com/olvrpl/NF3-BIG-DATA-RAPHAEL-LEONARDO-MONTEIRO-DE-OLIVEIRA/main/world_alcohol.csv', encoding = 'latin-1', delimiter =',')
tipo_de_bebidas = dados.groupby('Beverage Types').std()

tipo_de_bebidas
# Out:
# <ipython-input-26-674a8f274b7d>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tipo_de_bebidas = dados.groupby('Beverage Types').std()
#                     Year  Display Value
# Beverage Types
# Beer            1.899180       1.824993
# Other           1.547741       1.556937
# Spirits         1.364516       1.289285
# Wine            1.552500       1.730992

# %%
#1.b) Agrupe os dados por Região e por Ano;

import pandas as pd
dados = pd.read_csv('https://raw.githubusercontent.com/olvrpl/NF3-BIG-DATA-RAPHAEL-LEONARDO-MONTEIRO-DE-OLIVEIRA/main/world_alcohol.csv', encoding = 'latin-1', delimiter =',')
regiao_ano = dados.groupby(['WHO region', 'Year']).std()

regiao_ano
# Out:
# <ipython-input-30-c378af4024de>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   regiao_ano = dados.groupby(['WHO region', 'Year']).std()
#                             Display Value
# WHO region            Year
# Africa                1984       2.914807
#                       1985       0.574599
#                       1986       2.043331
#                       1987       0.084083
#                       1989       0.970884
# Americas              1984       1.237437
#                       1985            NaN
#                       1986       1.481154
#                       1987       1.076717
#                       1989       1.873814
# Eastern Mediterranean 1984       0.992814
#                       1985            NaN
#                       1986       0.401290
#                       1987       0.181246
#                       1989       0.005000
# Europe                1984       1.174660
#                       1985       2.708933
#                       1986       2.690011
#                       1987       1.056709
#                       1989       1.580327
# South-East Asia       1984            NaN
#                       1985            NaN
#                       1986       0.000000
# Western Pacific       1984       0.035355
#                       1985       0.035355
#                       1986       0.000000
#                       1987       0.077782

# %%
#1.c) Seção de Contagens: Contar a ocorrência de Regiões, de Países e a soma da coluna de valores por Bebida.

import pandas as pd
dados = pd.read_csv('https://raw.githubusercontent.com/olvrpl/NF3-BIG-DATA-RAPHAEL-LEONARDO-MONTEIRO-DE-OLIVEIRA/main/world_alcohol.csv')

contar_regioes = dados
contar_paises = dados['Country'].value_counts()
valores_por_bebida = dados.groupby('Beverage Types')['Display Value'].sum()

print(contar_regioes)
print(contar_paises)
print(valores_por_bebida)
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [100 rows x 5 columns]
# Viet Nam                                 4
# Ukraine                                  3
# Afghanistan                              2
# Suriname                                 2
# Somalia                                  2
#                                         ..
# Egypt                                    1
# Russian Federation                       1
# Micronesia (Federated States of)         1
# Sierra Leone                             1
# Democratic People's Republic of Korea    1
# Name: Country, Length: 80, dtype: int64
# Beverage Types
# Beer       35.50
# Other      14.93
# Spirits    30.97
# Wine       23.39
# Name: Display Value, dtype: float64

# %%
#1.d) Realize análises estatísticas da coluna dos valores: Média, Moda, Mediana, Estatística, Descritiva e Gráfico de comparação dos valores agrupados por tipo de bebida.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dados = pd.read_csv('https://raw.githubusercontent.com/olvrpl/NF3-BIG-DATA-RAPHAEL-LEONARDO-MONTEIRO-DE-OLIVEIRA/main/world_alcohol.csv')

media = dados['Display Value'].mean()
moda = dados['Display Value'].mode().values
mediana = dados['Display Value'].median()
descritiva = dados['Display Value'].describe()

dados.groupby('Beverage Types')['Display Value'].mean().plot(kind='bar')
plt.ylabel('Média dos Valores')
plt.title('Comparação dos Tipos de Bebidas')
plt.show()

print("Média:", media)
print("Moda:", moda)
print("Mediana:", mediana)
print("Estatística Descritiva:")
print(descritiva)
# Out:
# Média: 1.1030526315789473
# Moda: [0.]
# Mediana: 0.19
# Estatística Descritiva:
# count    95.000000
# mean      1.103053
# std       1.642623
# min       0.000000
# 25%       0.000000
# 50%       0.190000
# 75%       1.820000
# max       7.380000
# Name: Display Value, dtype: float64

# %%
#1.e) Mostre resultados de acordo com alguns critérios: i. Mostrar a coluna de bebidas do ano de 1985. ii. Mostrar a coluna de Região com valores acima de 4.

import pandas as pd
dados = pd.read_csv('https://raw.githubusercontent.com/olvrpl/NF3-BIG-DATA-RAPHAEL-LEONARDO-MONTEIRO-DE-OLIVEIRA/main/world_alcohol.csv')

ano = dados['Year'] == 1985
bebidas = dados.loc[ano, 'Beverage Types']
print("Mostrar a coluna de bebidas do ano de 1985:")
print(bebidas)
print()

filtro_regiao = dados['Display Value'] > 4
coluna_regiao_acima_de_4 = dados.loc[filtro_regiao, 'WHO region']
print("Mostrar a coluna de Região com valores acima de 4:")
print(coluna_regiao_acima_de_4)
# Out:
# Mostrar a coluna de bebidas do ano de 1985:
# 2        Wine
# 7     Spirits
# 12       Beer
# 14    Spirits
# 24      Other
# 26       Wine
# 33      Other
# 35    Spirits
# 44      Other
# 50      Other
# 63      Other
# 71      Other
# 76       Beer
# 77    Spirits
# 80      Other
# 81       Wine
# 85       Wine
# 94    Spirits
# 96       Wine
# 99       Wine
# Name: Beverage Types, dtype: object
#
# Mostrar a coluna de Região com valores acima de 4:
# 3     Americas
# 9       Africa
# 21    Americas
# 30      Africa
# 41      Europe
# 57      Europe
# 91      Europe
# 96      Europe
# Name: WHO region, dtype: object
